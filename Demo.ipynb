# %%
from PyONS.api.datasets import Datasets
import matplotlib.pyplot as plt

Datasets().Dataset('ashe-table-7-hours').edition()

# %%
x = Datasets().Dataset('mid-year-pop-est').edition('time-series').version(4).observation({'geography': 'Hartlepool'}).get()
x
# Out:
# https://api.beta.ons.gov.uk/v1/datasets/mid-year-pop-est/editions/time-series/versions/4/observations
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-12-fa0026673911> in <module>
# ----> 1 x = Datasets().Dataset('mid-year-pop-est').edition('time-series').version(4).observation().get()
#       2 x
#
# ~/Code/ons-api/PyONS/api/datasets.py in get(self)
#     154                base_url + '/datasets/{id}/editions/{edition}/versions/{version}/observations'.format(id = self.dataset_id, edition = self.edition, version = self.version))
#     155             print(r.url)
# --> 156             response = r.json()
#     157             return response
#     158
#
# ~/Code/ons-api/.venv/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# ...

# %%
Datasets().Dataset('mid-year-pop-est').edition('time-series').version('4').as_DataFrame()
# Out:
#          V4_0  calendar-years  time admin-geography   geography  \
# 0         415            2017  2017       E06000001  Hartlepool
# 1        1060            2017  2017       E06000001  Hartlepool
# 2        1165            2017  2017       E06000001  Hartlepool
# 3        1177            2017  2017       E06000001  Hartlepool
# 4        1421            2017  2017       E06000001  Hartlepool
# ...       ...             ...   ...             ...         ...
# 728635  29955            2012  2012       W92000004       Wales
# 728636  17469            2012  2012       W92000004       Wales
# 728637  18736            2012  2012       W92000004       Wales
# 728638   3488            2012  2012       W92000004       Wales
# 728639  20317            2012  2012       W92000004       Wales
#
#        mid-year-pop-age age  mid-year-pop-sex     sex
# 0                    39  39                 1    Male
# 1                     2   2                 0     All
# ...

# %%
Datasets().as_DataFrame()
# Out:
# ..
# 20  {'editions': {'href': 'https://api.beta.ons.go...
# 21  {'editions': {'href': 'https://api.beta.ons.go...
# 22  {'editions': {'href': 'https://api.beta.ons.go...
# 23  {'editions': {'href': 'https://api.beta.ons.go...
# 24  {'editions': {'href': 'https://api.beta.ons.go...
# 25  {'editions': {'href': 'https://api.beta.ons.go...
# 26  {'editions': {'href': 'https://api.beta.ons.go...
# 27  {'editions': {'href': 'https://api.beta.ons.go...
# 28  {'editions': {'href': 'https://api.beta.ons.go...
# 29  {'editions': {'href': 'https://api.beta.ons.go...
# 30  {'editions': {'href': 'https://api.beta.ons.go...
# 31  {'editions': {'href': 'https://api.beta.ons.go...
# 32  {'editions': {'href': 'https://api.beta.ons.go...
#
#                                         methodologies national_statistic  \
# 0   [{'description': 'Details how measures of cons...               True
# 1   [{'description': 'Background information and m...               True
# ...
